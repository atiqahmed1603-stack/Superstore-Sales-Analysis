# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\moham\Downloads\train.csv\train.csv")

# %%
df.shape
# Out:
# (9800, 18)

# %%
df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 1       2  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 2       3  CA-2017-138688  12/06/2017  16/06/2017    Second Class    DV-13045
# 3       4  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
# 4       5  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 9800 entries, 0 to 9799
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9800 non-null   int64
#  1   Order ID       9800 non-null   str
#  2   Order Date     9800 non-null   str
#  3   Ship Date      9800 non-null   str
#  4   Ship Mode      9800 non-null   str
#  5   Customer ID    9800 non-null   str
#  6   Customer Name  9800 non-null   str
#  7   Segment        9800 non-null   str
#  8   Country        9800 non-null   str
#  9   City           9800 non-null   str
#  10  State          9800 non-null   str
#  11  Postal Code    9789 non-null   float64
#  12  Region         9800 non-null   str
#  13  Product ID     9800 non-null   str
#  14  Category       9800 non-null   str
#  15  Sub-Category   9800 non-null   str
#  16  Product Name   9800 non-null   str
#  17  Sales          9800 non-null   float64
# dtypes: float64(2), int64(1), str(15)
# ...

# %%
df.isnull().sum()
# Out:
# Row ID            0
# Order ID          0
# Order Date        0
# Ship Date         0
# Ship Mode         0
# Customer ID       0
# Customer Name     0
# Segment           0
# Country           0
# City              0
# State             0
# Postal Code      11
# Region            0
# Product ID        0
# Category          0
# Sub-Category      0
# Product Name      0
# Sales             0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df[['Order Date', 'Ship Date']].head(10)
# Out:
#    Order Date   Ship Date
# 0  08/11/2017  11/11/2017
# 1  08/11/2017  11/11/2017
# 2  12/06/2017  16/06/2017
# 3  11/10/2016  18/10/2016
# 4  11/10/2016  18/10/2016
# 5  09/06/2015  14/06/2015
# 6  09/06/2015  14/06/2015
# 7  09/06/2015  14/06/2015
# 8  09/06/2015  14/06/2015
# 9  09/06/2015  14/06/2015

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'], dayfirst=True)
df['Ship Date'] = pd.to_datetime(df['Ship Date'], dayfirst=True)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 9800 entries, 0 to 9799
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9800 non-null   int64
#  1   Order ID       9800 non-null   str
#  2   Order Date     9800 non-null   datetime64[us]
#  3   Ship Date      9800 non-null   datetime64[us]
#  4   Ship Mode      9800 non-null   str
#  5   Customer ID    9800 non-null   str
#  6   Customer Name  9800 non-null   str
#  7   Segment        9800 non-null   str
#  8   Country        9800 non-null   str
#  9   City           9800 non-null   str
#  10  State          9800 non-null   str
#  11  Postal Code    9789 non-null   float64
#  12  Region         9800 non-null   str
#  13  Product ID     9800 non-null   str
#  14  Category       9800 non-null   str
#  15  Sub-Category   9800 non-null   str
#  16  Product Name   9800 non-null   str
#  17  Sales          9800 non-null   float64
# ...

# %%
df['Order Date'].min(), df['Order Date'].max()
# Out:
# (Timestamp('2015-01-03 00:00:00'), Timestamp('2018-12-30 00:00:00'))

# %%
df['Sales'].describe()
# Out:
# count     9800.000000
# mean       230.769059
# std        626.651875
# min          0.444000
# 25%         17.248000
# 50%         54.490000
# 75%        210.605000
# max      22638.480000
# Name: Sales, dtype: float64

# %%
df['Order ID'].unique()
# Out:
# <ArrowStringArray>
# ['CA-2017-152156', 'CA-2017-138688', 'US-2016-108966', 'CA-2015-115812',
#  'CA-2018-114412', 'CA-2017-161389', 'US-2016-118983', 'CA-2015-105893',
#  'CA-2015-167164', 'CA-2015-143336',
#  ...
#  'CA-2017-160234', 'CA-2015-169019', 'CA-2017-153178', 'CA-2016-149748',
#  'CA-2016-155635', 'US-2015-114377', 'CA-2018-144491', 'CA-2015-127166',
#  'CA-2017-125920', 'CA-2016-128608']
# Length: 4922, dtype: str

# %%
df['Customer ID'].nunique()
# Out:
# 793

# %%
df['Segment'].unique()
# Out:
# <ArrowStringArray>
# ['Consumer', 'Corporate', 'Home Office']
# Length: 3, dtype: str

# %%
df['Category'].unique()
# Out:
# <ArrowStringArray>
# ['Furniture', 'Office Supplies', 'Technology']
# Length: 3, dtype: str

# %%
df['Sub-Category'].unique()
# Out:
# <ArrowStringArray>
# [  'Bookcases',      'Chairs',      'Labels',      'Tables',     'Storage',
#  'Furnishings',         'Art',      'Phones',     'Binders',  'Appliances',
#        'Paper', 'Accessories',   'Envelopes',   'Fasteners',    'Supplies',
#     'Machines',     'Copiers']
# Length: 17, dtype: str

# %%
df['Ship Mode'].unique()
# Out:
# <ArrowStringArray>
# ['Second Class', 'Standard Class', 'First Class', 'Same Day']
# Length: 4, dtype: str

# %%
df['Country'].unique()
# Out:
# <ArrowStringArray>
# ['United States']
# Length: 1, dtype: str

# %%
df['Country'].nunique()
# Out:
# 1

# %%
df.groupby('Product Name')['Sales'].sum().sort_values(ascending=False).head(10)
# Out:
# Product Name
# Canon imageCLASS 2200 Advanced Copier                                          61599.824
# Fellowes PB500 Electric Punch Plastic Comb Binding Machine with Manual Bind    27453.384
# Cisco TelePresence System EX90 Videoconferencing Unit                          22638.480
# HON 5400 Series Task Chairs for Big and Tall                                   21870.576
# GBC DocuBind TL300 Electric Binding System                                     19823.479
# GBC Ibimaster 500 Manual ProClick Binding System                               19024.500
# Hewlett Packard LaserJet 3310 Copier                                           18839.686
# HP Designjet T520 Inkjet Large Format Printer - 24" Color                      18374.895
# GBC DocuBind P400 Electric Binding System                                      17965.068
# High Speed Automatic Electric Letter Opener                                    17030.312
# Name: Sales, dtype: float64

# %%
df.groupby('Category')['Sales'].sum().sort_values(ascending=False)
# Out:
# Category
# Technology         827455.8730
# Furniture          728658.5757
# Office Supplies    705422.3340
# Name: Sales, dtype: float64

# %%
df.groupby('State')['Sales'].sum().sort_values(ascending=False).head(10)
# Out:
# State
# California      446306.4635
# New York        306361.1470
# Texas           168572.5322
# Washington      135206.8500
# Pennsylvania    116276.6500
# Florida          88436.5320
# Illinois         79236.5170
# Michigan         76136.0740
# Ohio             75130.3500
# Virginia         70636.7200
# Name: Sales, dtype: float64

# %%
df.groupby(df['Order Date'].dt.year)['Sales'].sum()
# Out:
# Order Date
# 2015    479856.2081
# 2016    459436.0054
# 2017    600192.5500
# 2018    722052.0192
# Name: Sales, dtype: float64

# %%
df.groupby(df['Order Date'].dt.month)['Sales'].sum().sort_values(ascending=False)
# Out:
# Order Date
# 11    350161.7110
# 12    321480.1695
# 9     300103.4117
# 10    199496.2947
# 3     197573.5872
# 8     157315.9270
# 5     154086.7237
# 6     145837.5233
# 7     145535.6890
# 4     136283.0006
# 1      94291.6296
# 2      59371.1154
# Name: Sales, dtype: float64

# %%
df.groupby([df['Order Date'].dt.year, df['Order Date'].dt.month])['Sales'].sum()
# Out:
# Order Date  Order Date
# 2015        1              14205.7070
#             2               4519.8920
#             3              55205.7970
#             4              27906.8550
#             5              23644.3030
#             6              34322.9356
#             7              33781.5430
#             8              27117.5365
#             9              81623.5268
#             10             31453.3930
#             11             77907.6607
#             12             68167.0585
# 2016        1              18066.9576
#             2              11951.4110
#             3              32339.3184
#             4              34154.4685
#             5              29959.5305
#             6              23599.3740
#             7              28608.2590
#             8              36818.3422
#             9              63133.6060
#             10             31011.7375
#             11             75249.3995
#             12             74543.6012
# ...

# %%
yearly_sales = df.groupby(df['Order Date'].dt.year)['Sales'].sum()

yearly_growth = yearly_sales.pct_change()*100

yearly_growth
# Out:
# Order Date
# 2015          NaN
# 2016    -4.255484
# 2017    30.636812
# 2018    20.303396
# Name: Sales, dtype: float64

# %%
df.groupby([df['Order Date'].dt.year, 'Category'])['Sales'].sum()
# Out:
# Order Date  Category
# 2015        Furniture          156477.8811
#             Office Supplies    149512.8200
#             Technology         173865.5070
# 2016        Furniture          164053.8674
#             Office Supplies    133124.4070
#             Technology         162257.7310
# 2017        Furniture          195813.0400
#             Office Supplies    182417.5660
#             Technology         221961.9440
# 2018        Furniture          212313.7872
#             Office Supplies    240367.5410
#             Technology         269370.6910
# Name: Sales, dtype: float64

# %%
df.groupby('Sub-Category')['Sales'].sum().sort_values(ascending=False)
# Out:
# Sub-Category
# Phones         327782.4480
# Chairs         322822.7310
# Storage        219343.3920
# Tables         202810.6280
# Binders        200028.7850
# Machines       189238.6310
# Accessories    164186.7000
# Copiers        146248.0940
# Bookcases      113813.1987
# Appliances     104618.4030
# Furnishings     89212.0180
# Paper           76828.3040
# Supplies        46420.3080
# Art             26705.4100
# Envelopes       16128.0460
# Labels          12347.7260
# Fasteners        3001.9600
# Name: Sales, dtype: float64

# %%
subcat_yearly =df.groupby([df['Order Date'].dt.year, 'Sub-Category'])['Sales'].sum().unstack()

subcat_yearly
# Out:
# Sub-Category  Accessories  Appliances       Art    Binders   Bookcases  \
# Order Date
# 2015            23766.396   15160.715  5897.534  43263.267  20036.6776
# 2016            40443.970   23228.179  6091.636  36049.746  37476.7749
# 2017            41735.364   26016.787  5890.608  48994.517  26275.4665
# 2018            58240.970   40212.722  8825.632  71721.255  30024.2797
#
# Sub-Category     Chairs    Copiers  Envelopes  Fasteners  Furnishings  \
# Order Date
# 2015          77046.440  10849.782   3844.590    655.388    13636.986
# 2016          70654.673  26179.450   4448.218    545.224    20525.224
# 2017          81930.345  46319.474   4456.664    946.274    26845.116
# 2018          93191.273  62899.388   3378.574    855.074    28204.692
#
# Sub-Category    Labels   Machines      Paper      Phones    Storage  \
# Order Date
# 2015          2825.458  62023.373  14332.722   77225.956  49197.526
# 2016          2884.912  27763.697  14664.762   67870.614  43321.208
# ...

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales'],
#       dtype='str')

# %%
df.groupby('Segment')['Customer ID'].nunique().sort_values(ascending=False)
# Out:
# Segment
# Consumer       409
# Corporate      236
# Home Office    148
# Name: Customer ID, dtype: int64

# %%
segment_sales = df.groupby('Segment')['Sales'].sum()
segment_customers = df.groupby('Segment')['Customer ID'].nunique()
sales_per_customer = (segment_sales/ segment_customers).sort_values(ascending=False)
sales_per_customer
# Out:
# Segment
# Corporate      2917.347775
# Home Office    2871.501195
# Consumer       2806.993963
# dtype: float64

# %%
customer_orders = df.groupby('Customer ID')['Order ID'].nunique()
customer_orders.describe()
# Out:
# count    793.000000
# mean       6.206810
# std        2.525647
# min        1.000000
# 25%        4.000000
# 50%        6.000000
# 75%        8.000000
# max       17.000000
# Name: Order ID, dtype: float64

# %%
customer_orders.sort_values(ascending=False).head(10)
# Out:
# Customer ID
# EP-13915    17
# ZC-21910    13
# CK-12205    13
# JE-15745    13
# PG-18820    13
# SH-19975    12
# RP-19390    12
# SJ-20125    12
# BP-11095    12
# NS-18640    12
# Name: Order ID, dtype: int64

# %%
one_time_customers = (customer_orders==1).sum()
repeat_customers = (customer_orders > 1 ).sum()

print('One-time customers:', one_time_customers)
print('Repeat customers:', repeat_customers)
# Out:
# One-time customers: 13
# Repeat customers: 780

# %%
repeat_rate = repeat_customers/ len (customer_orders)*100

print(f"Repeat customer rate : {repeat_rate:.2f}%")
# Out:
# Repeat customer rate : 98.36%

# %%
customer_sales = df.groupby('Customer ID')['Sales'].sum()

customer_sales.sort_values(ascending=False).head(10)
# Out:
# Customer ID
# SM-20320    25043.050
# TC-20980    19052.218
# RB-19360    15117.339
# TA-21385    14595.620
# AB-10105    14473.571
# KL-16645    14175.229
# SC-20095    14142.334
# HL-15040    12873.298
# SE-20110    12209.438
# CC-12370    12129.072
# Name: Sales, dtype: float64

# %%
top_customer = customer_sales.idxmax()

df[df['Customer ID']==top_customer][['Customer ID', 'Customer Name', 'Order ID', 'Order Date','Category','Sub-Category', 'Product Name','Sales']]
# Out:
#      Customer ID Customer Name        Order ID Order Date         Category  \
# 2266    SM-20320   Sean Miller  CA-2018-149146 2018-10-12  Office Supplies
# 2573    SM-20320   Sean Miller  CA-2018-145128 2018-07-09        Furniture
# 2696    SM-20320   Sean Miller  CA-2015-145317 2015-03-18       Technology
# 2697    SM-20320   Sean Miller  CA-2015-145317 2015-03-18       Technology
# 2698    SM-20320   Sean Miller  CA-2015-145317 2015-03-18  Office Supplies
# 2699    SM-20320   Sean Miller  CA-2015-145317 2015-03-18  Office Supplies
# 2700    SM-20320   Sean Miller  CA-2015-145317 2015-03-18        Furniture
# 2701    SM-20320   Sean Miller  CA-2015-145317 2015-03-18  Office Supplies
# 2702    SM-20320   Sean Miller  CA-2015-145317 2015-03-18        Furniture
# 7853    SM-20320   Sean Miller  CA-2016-144890 2016-12-25  Office Supplies
# 9187    SM-20320   Sean Miller  US-2016-130512 2016-08-21  Office Supplies
# ...

# %%
df[df['Customer ID']==top_customer].groupby('Category')['Sales'].sum().sort_values(ascending=False)
# Out:
# Category
# Technology         23481.508
# Office Supplies      881.972
# Furniture            679.570
# Name: Sales, dtype: float64

# %%
top_customer_category = (df[df['Customer ID'] == top_customer].groupby('Category')['Sales'].sum())

top_customer_category_pct = (top_customer_category / top_customer_category.sum() *100).sort_values(ascending=False)

top_customer_category_pct
# Out:
# Category
# Technology         93.764569
# Office Supplies     3.521823
# Furniture           2.713607
# Name: Sales, dtype: float64

# %%
top_10_sales = customer_sales.sort_values(ascending=False).head(10).sum()

total_sales = df['Sales'].sum()

top_10_percentage = top_10_sales / total_sales * 100

print(f"Top 10 customers contribute {top_10_percentage:.2f}% of total sales")
# Out:
# Top 10 customers contribute 6.80% of total sales

# %%
product_sales = df.groupby('Product Name')['Sales'].sum()

product_sales.sort_values(ascending=False).head(10)
# Out:
# Product Name
# Canon imageCLASS 2200 Advanced Copier                                          61599.824
# Fellowes PB500 Electric Punch Plastic Comb Binding Machine with Manual Bind    27453.384
# Cisco TelePresence System EX90 Videoconferencing Unit                          22638.480
# HON 5400 Series Task Chairs for Big and Tall                                   21870.576
# GBC DocuBind TL300 Electric Binding System                                     19823.479
# GBC Ibimaster 500 Manual ProClick Binding System                               19024.500
# Hewlett Packard LaserJet 3310 Copier                                           18839.686
# HP Designjet T520 Inkjet Large Format Printer - 24" Color                      18374.895
# GBC DocuBind P400 Electric Binding System                                      17965.068
# High Speed Automatic Electric Letter Opener                                    17030.312
# Name: Sales, dtype: float64

# %%
product_orders = df.groupby('Product Name')['Order ID'].nunique()
product_orders.sort_values(ascending=False).head(10)
# Out:
# Product Name
# Staple envelope                               47
# Staples                                       46
# Easy-staple paper                             44
# Avery Non-Stick Binders                       20
# Staple remover                                18
# Staples in misc. colors                       18
# Storex Dura Pro Binders                       17
# KI Adjustable-Height Table                    17
# Staple-based wall hangings                    16
# Situations Contoured Folding Chairs, 4/Set    15
# Name: Order ID, dtype: int64

# %%
product_avg_sales= product_sales/ product_orders

product_avg_sales.sort_values(ascending=False).head(10)
# Out:
# Product Name
# Cisco TelePresence System EX90 Videoconferencing Unit                    22638.480000
# Canon imageCLASS 2200 Advanced Copier                                    12319.964800
# Cubify CubeX 3D Printer Triple Head Print                                 7999.980000
# 3D Systems Cube Printer, 2nd Generation, Magenta                          7149.945000
# HP Designjet T520 Inkjet Large Format Printer - 24" Color                 6124.965000
# High Speed Automatic Electric Letter Opener                               5676.770667
# Ibico EPK-21 Electric Binding System                                      5291.972000
# Lexmark MX611dhe Monochrome Laser Printer                                 4207.475250
# Canon imageCLASS MF7460 Monochrome Digital Laser Multifunction Copier     3991.980000
# Okidata MB760 Printer                                                     3917.200000
# dtype: float64

# %%
state_sales = df.groupby('State')['Sales'].sum()
state_sales.sort_values(ascending=False).head(10)
# Out:
# State
# California      446306.4635
# New York        306361.1470
# Texas           168572.5322
# Washington      135206.8500
# Pennsylvania    116276.6500
# Florida          88436.5320
# Illinois         79236.5170
# Michigan         76136.0740
# Ohio             75130.3500
# Virginia         70636.7200
# Name: Sales, dtype: float64

# %%
state_customers = df.groupby('State')['Customer ID'].nunique()
state_customers.sort_values(ascending=False).head(10)
# Out:
# State
# California        570
# New York          409
# Texas             367
# Pennsylvania      255
# Illinois          231
# Washington        223
# Ohio              196
# Florida           178
# North Carolina    120
# Virginia          107
# Name: Customer ID, dtype: int64

# %%
state_sales_per_customer = state_sales/state_customers

state_sales_per_customer.sort_values(ascending=False).head(10)
# Out:
# State
# Vermont                 1785.874000
# Wyoming                 1603.136000
# Rhode Island             938.542750
# Missouri                 793.041071
# California               782.993796
# New York                 749.049259
# Nevada                   727.352261
# Indiana                  727.140299
# Michigan                 725.105467
# District of Columbia     716.255000
# dtype: float64

# %%
state_analysis = pd.DataFrame({
    'Total Sales' : state_sales,
    'Customers'   : state_customers,
    'Sales per Customer' : state_sales_per_customer
}) 

state_analysis.sort_values(
    'Total Sales',
    ascending=False
).head(10)
# Out:
#               Total Sales  Customers  Sales per Customer
# State
# California    446306.4635        570          782.993796
# New York      306361.1470        409          749.049259
# Texas         168572.5322        367          459.325701
# Washington    135206.8500        223          606.308744
# Pennsylvania  116276.6500        255          455.986863
# Florida        88436.5320        178          496.834449
# Illinois       79236.5170        231          343.015225
# Michigan       76136.0740        105          725.105467
# Ohio           75130.3500        196          383.318112
# Virginia       70636.7200        107          660.156262

# %%
state_avg_order_value = (
    df.groupby('State')['Sales']
    .mean()
    .sort_values(ascending=False)
)

state_avg_order_value.head(10)
# Out:
# State
# Wyoming         1603.136000
# Vermont          811.760909
# Nevada           428.951333
# Rhode Island     409.545927
# Montana          372.623467
# Indiana          360.877037
# Missouri         336.441667
# Minnesota        335.541011
# Alabama          319.846557
# Virginia         315.342500
# Name: Sales, dtype: float64

# %%
state_orders = df.groupby('State')['Order ID'].nunique()
state_orders.sort_values(ascending=False).head(10)
# Out:
# State
# California        1002
# New York           547
# Texas              480
# Pennsylvania       285
# Illinois           270
# Washington         254
# Ohio               227
# Florida            197
# North Carolina     134
# Michigan           116
# Name: Order ID, dtype: int64

# %%
state_analysis['Orders'] = state_orders

state_analysis.sort_values('Total Sales',ascending=False).head(10)
# Out:
#               Total Sales  Customers  Sales per Customer  Orders
# State
# California    446306.4635        570          782.993796    1002
# New York      306361.1470        409          749.049259     547
# Texas         168572.5322        367          459.325701     480
# Washington    135206.8500        223          606.308744     254
# Pennsylvania  116276.6500        255          455.986863     285
# Florida        88436.5320        178          496.834449     197
# Illinois       79236.5170        231          343.015225     270
# Michigan       76136.0740        105          725.105467     116
# Ohio           75130.3500        196          383.318112     227
# Virginia       70636.7200        107          660.156262     115

# %%
texas_category_sales =(
    df[df['State']=='Texas']
    .groupby('Category')['Sales']
    .sum()
    .sort_values(ascending=False))

texas_category_sales
# Out:
# Category
# Technology         64656.2720
# Furniture          59633.6442
# Office Supplies    44282.6160
# Name: Sales, dtype: float64

# %%
state_category_sales = (
    df[df['State'].isin(['Texas', 'Michigan'])]
    .groupby(['State', 'Category',])['Sales']
    .sum()
    .unstack()
)

state_category_sales
# Out:
# Category   Furniture  Office Supplies  Technology
# State
# Michigan  22321.1000        37688.199   16126.775
# Texas     59633.6442        44282.616   64656.272

# %%
state_category_customer = (
    df[df['State'].isin(['Texas', 'Michigan'])]
    .groupby(['State', 'Category'])['Customer ID']
    .nunique()
    .unstack()
)

state_category_customer
# Out:
# Category  Furniture  Office Supplies  Technology
# State
# Michigan         40               89          31
# Texas           156              288         144

# %%
state_category_avg = (
    df[df['State'].isin(['Texas', 'Michigan'])]
    .groupby(['State', 'Category'])
    .agg(
        Sales=('Sales', 'sum'),
        Customers = ('Customer ID', 'nunique')
    )
)
state_category_avg['sales_per_customer']= (
    state_category_avg['Sales'] /state_category_avg['Customers']
)

state_category_avg
# Out:
#                                Sales  Customers  sales_per_customer
# State    Category
# Michigan Furniture        22321.1000         40          558.027500
#          Office Supplies  37688.1990         89          423.462910
#          Technology       16126.7750         31          520.218548
# Texas    Furniture        59633.6442        156          382.266950
#          Office Supplies  44282.6160        288          153.759083
#          Technology       64656.2720        144          449.001889

# %%
monthly_sales=(
    df.groupby(df['Order Date'].dt.to_period('M'))['Sales']
    .sum()
)

monthly_sales.sort_values(ascending=False).head(10)
# Out:
# Order Date
# 2018-11    117938.1550
# 2017-12     95739.1210
# 2018-09     86152.8880
# 2018-12     83030.3888
# 2015-09     81623.5268
# 2017-11     79066.4958
# 2015-11     77907.6607
# 2018-10     77448.1312
# 2016-11     75249.3995
# 2016-12     74543.6012
# Freq: M, Name: Sales, dtype: float64

# %%
monthly_avg = (
    df.groupby(df['Order Date'].dt.month)['Sales']
               .mean())

monthly_avg.sort_values(ascending=False)
# Out:
# Order Date
# 3     290.549393
# 1     257.627403
# 10    246.596162
# 11    241.657496
# 12    232.619515
# 8     227.007110
# 9     221.642106
# 5     212.533412
# 6     211.052856
# 7     208.802997
# 4     207.432269
# 2     199.902745
# Name: Sales, dtype: float64

# %%
monthly_total = (
    df.groupby([
        df['Order Date'].dt.year,
        df['Order Date'].dt.month
    ])['Sales']
    .sum()
)

monthly_avg_total = (
    monthly_total
    .groupby(level=1)
    .mean()
)

monthly_avg_total.sort_values(ascending=False)
# Out:
# Order Date
# 11    87540.427750
# 12    80370.042375
# 9     75025.852925
# 10    49874.073675
# 3     49393.396800
# 8     39328.981750
# 5     38521.680925
# 6     36459.380825
# 7     36383.922250
# 4     34070.750150
# 1     23572.907400
# 2     14842.778850
# Name: Sales, dtype: float64

# %%
november_Sales = (
    df[df['Order Date'].dt.month == 11]
    .groupby('Category')['Sales']
    .sum()
    .sort_values(ascending=False)

)
november_Sales
# Out:
# Category
# Technology         130497.187
# Furniture          120508.885
# Office Supplies     99155.639
# Name: Sales, dtype: float64

# %%
november_product_sales = (
df[df['Order Date'].dt.month==1]
.groupby('Product Name')['Sales']
.sum()
.sort_values(ascending=False)
)

november_product_sales.head(10)
# Out:
# Product Name
# GBC DocuBind P400 Electric Binding System                   5443.960
# Chromcraft Bull-Nose Wood Oval Conference Tables & Bases    4297.644
# Martin Yale Chadless Opener Electric Letter Opener          4164.050
# Lexmark MX611dhe Monochrome Laser Printer                   3059.982
# Canon Image Class D660 Copier                               2999.950
# Samsung Galaxy Mega 6.3                                     2939.930
# HON 5400 Series Task Chairs for Big and Tall                2803.920
# Global Deluxe High-Back Manager's Chair                     2573.820
# GBC ProClick 150 Presentation Binding System                2022.272
# Samsung Galaxy S4                                           2003.168
# Name: Sales, dtype: float64

# %%
top_10_november_sales = november_product_sales.head(10).sum()

november_total_sales = df[df['Order Date'].dt.month ==11]['Sales'].sum()

top_10_november_pct = (
    top_10_november_sales/november_total_sales*100
)

print (f'Top 10 Products contributed {top_10_november_pct:.2f}% of November Sales')
# Out:
# Top 10 Products contributed 9.23% of November Sales

# %%
november_category_orders = (
    df[df['Order Date'].dt.month==11]
    .groupby ('Category')['Order ID']
    .nunique()
    .sort_values(ascending=False)
)

november_category_orders
# Out:
# Category
# Office Supplies    530
# Furniture          267
# Technology         246
# Name: Order ID, dtype: int64

# %%
november_aov = ( 
    df[df['Order Date'].dt.month== 11]
    .groupby('Category') ['Sales']
    .sum()
    /november_category_orders
)

november_aov.sort_values(ascending = False)
# Out:
# Category
# Technology         530.476370
# Furniture          451.344139
# Office Supplies    187.086111
# dtype: float64

# %%
november_yearly_sales = (
    df[df['Order Date'].dt.month==11]
    .groupby(df['Order Date'].dt.year)['Sales']
    .sum()
    .sort_values(ascending=False)
)

november_yearly_Sales
# Out:
# Order Date
# 2018    117938.1550
# 2017     79066.4958
# 2015     77907.6607
# 2016     75249.3995
# Name: Sales, dtype: float64

# %%
november_yearly_sales= (
    df[df['Order Date'].dt.month==11]
    .groupby(df[df['Order Date'].dt.month ==11]['Order Date'].dt.year)['Sales']
             .sum()
             .sort_index()
)
november_yearly_growth = november_yearly_sales.pct_change()*100

november_yearly_growth
# Out:
# Order Date
# 2015          NaN
# 2016    -3.412067
# 2017     5.072594
# 2018    49.163250
# Name: Sales, dtype: float64

# %%
november_category_year = (
    df[df['Order Date'].dt.month==11]
    .groupby([
        df[df['Order Date'].dt.month ==11]['Order Date'].dt.year,
        'Category'
    ])['Sales']
    .sum()
    .unstack()
    )


november_category_year
# Out:
# Category     Furniture  Office Supplies  Technology
# Order Date
# 2015        21471.0407        26363.196   30073.424
# 2016        30197.5005        21178.298   23873.601
# 2017        31783.6288        20141.808   27141.059
# 2018        37056.7150        31472.337   49409.103

# %%
category_growth = (
    (november_category_year.loc[2018]-
     november_category_year.loc[2017])
     /november_category_year.loc[2017]*100)


category_growth=category_growth.sort_values(ascending=False)


category_growth
# Out:
# Category
# Technology         82.045597
# Office Supplies    56.253783
# Furniture          16.590573
# dtype: float64

# %%
technology_november = (
    df[
        (df['Order Date'].dt.month==11)&
        (df['Category']== 'Technology')
    ]
    .groupby([
        df['Order Date'].dt.year,
        'Product Name'
    ])['Sales']
    .sum()
    .unstack(fill_value=0)
)

technology_november
# Out:
# Product Name  3D Systems Cube Printer, 2nd Generation, White  AT&T 1080 Phone  \
# Order Date
# 2015                                                   0.000            0.000
# 2016                                                   0.000            0.000
# 2017                                                   0.000          657.552
# 2018                                                1039.992            0.000
#
# Product Name  AT&T 17929 Lendline Telephone  AT&T CL82213  AT&T SB67148 SynJ  \
# Order Date
# 2015                                  0.000        46.384               0.00
# 2016                                226.200         0.000               0.00
# 2017                                 36.192         0.000             263.96
# 2018                                  0.000         0.000               0.00
#
# Product Name  AT&T TR1909W  Aastra 6757i CT Wireless VoIP phone  \
# Order Date
# 2015                503.96                                0.000
# ...

# %%
technology_growth = (
    technology_november.loc[[2017,2018]].T
)

technology_growth['Growth']=(
    technology_growth[2018]-technology_growth[2017]
)

technology_growth = (
    technology_growth
    .sort_values('Growth', ascending = False)
)

technology_growth.head(10)
# Out:
# Order Date                                             2017       2018  \
# Product Name
# Canon imageCLASS 2200 Advanced Copier                 0.000  10499.970
# Cubify CubeX 3D Printer Triple Head Print             0.000   7999.980
# Google Nexus 5                                        0.000   1979.890
# Samsung Galaxy Mega 6.3                               0.000   1931.954
# Bady BDG101FRU Card Printer                           0.000   1919.976
# Samsung Galaxy S4 Mini                                0.000   1879.960
# Logitech diNovo Edge Keyboard                       499.980   2249.910
# Motorola Moto X                                     271.992   1359.960
# 3D Systems Cube Printer, 2nd Generation, White        0.000   1039.992
# Plantronics Calisto P620-M USB Wireless Speaker...    0.000    979.950
#
# Order Date                                             Growth
# Product Name
# Canon imageCLASS 2200 Advanced Copier               10499.970
# ...

# %%
technology_growth_top10 =  technology_growth.head(10)['Growth'].sum()

technology_total_growth = (
    november_category_year.loc[2018, 'Technology']
    - november_category_year.loc[2017, 'Technology']
)

top10_contribution = (
    technology_growth_top10/technology_total_growth*100
)

print (f'Top 10 Technology products contributed {top10_contribution:.2f}% of Technology growth.')
# Out:
# Top 10 Technology products contributed 139.53% of Technology growth.

# %%
technology_growth.head(10).sort_values('Growth').plot(kind='barh',y='Growth', figsize=(10,6),legend=False, 
                                                      title='Top 10 Technology products by November Sales Growth')

plt.xlabel('Sales Growth($)')
plt.ylabel('Product Name')
plt.tight_layout()
plt.show()

# %%
november_category_sales = (
    df[df['Order Date'].dt.month==11]
    .groupby('Category')['Sales']
    .sum()
    .sort_values()
)
november_category_sales.plot(
    kind='barh',
    figsize=(8,5),
    title= ' November Sales by category'
)

plt.xlabel('Sales($)')
plt.ylabel('category')
plt.tight_layout()
plt.show()

# %%
november_year_category = (
    df[df['Order Date'].dt.month==11]
    .groupby([
        df[df['Order Date'].dt.month==11]['Order Date'].dt.year,
        'Category'
    ])['Sales']
    .sum()
    .unstack()
)

november_year_category.loc[[2017,2018]].plot(
    kind='bar',
    figsize=(9,5),
    title = 'November Sales: 2017 vs 2018'
)

plt.xlabel('Year')
plt.ylabel('Sales ($)')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
monthly_sales =( df.groupby(df['Order Date'].dt.to_period('M'))['Sales'].sum())

monthly_sales.head()
# Out:
# Order Date
# 2015-01    14205.707
# 2015-02     4519.892
# 2015-03    55205.797
# 2015-04    27906.855
# 2015-05    23644.303
# Freq: M, Name: Sales, dtype: float64

# %%
monthly_sales.plot(
    kind='line',
    figsize= (12,5),
    title= 'Monthly Sales Trend'

)

plt.xlabel('Month')
plt.ylabel('Sales($)')
plt.tight_layout()
plt.show()

# %%
top_5_months = monthly_sales.sort_values(ascending=False).head(5)

top_5_months
# Out:
# Order Date
# 2018-11    117938.1550
# 2017-12     95739.1210
# 2018-09     86152.8880
# 2018-12     83030.3888
# 2015-09     81623.5268
# Freq: M, Name: Sales, dtype: float64

# %%
bottom_5_months = monthly_sales.sort_values().head(5)

bottom_5_months
# Out:
# Order Date
# 2015-02     4519.8920
# 2016-02    11951.4110
# 2015-01    14205.7070
# 2016-01    18066.9576
# 2017-01    18542.4910
# Freq: M, Name: Sales, dtype: float64

# %%
monthly_seasonality = (
    df.groupby(df['Order Date'].dt.month)['Sales']
    .sum()
)

monthly_seasonality

monthly_seasonality.index=[
    'Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun','jul','Aug','Sep','Oct','Nov','Dec']

monthly_seasonality
# Out:
# Jan     94291.6296
# Feb     59371.1154
# Mar    197573.5872
# Apr    136283.0006
# May    154086.7237
# Jun    145837.5233
# jul    145535.6890
# Aug    157315.9270
# Sep    300103.4117
# Oct    199496.2947
# Nov    350161.7110
# Dec    321480.1695
# Name: Sales, dtype: float64

# %%
monthly_seasonality.sort_values(ascending=False)
# Out:
# Nov    350161.7110
# Dec    321480.1695
# Sep    300103.4117
# Oct    199496.2947
# Mar    197573.5872
# Aug    157315.9270
# May    154086.7237
# Jun    145837.5233
# jul    145535.6890
# Apr    136283.0006
# Jan     94291.6296
# Feb     59371.1154
# Name: Sales, dtype: float64

# %%
peak_month = monthly_seasonality.idxmax()
peak_sales = monthly_seasonality.max()

lowest_month = monthly_seasonality.idxmin()
lowest_sales = monthly_seasonality.min()

difference = peak_sales - lowest_sales
percentage_difference = (difference/lowest_sales) *100

print(f'Peak month:{peak_month}(${peak_sales:,.2f})')
print(f'Lowest month: {lowest_month}(${lowest_sales:,.2f})')
print (f'Differnce: ${difference:,.2f}')
print(f'Peak month is {percentage_difference:.2f}% higher than the lowest month.')
# Out:
# Peak month:Nov($350,161.71)
# Lowest month: Feb($59,371.12)
# Differnce: $290,790.60
# Peak month is 489.78% higher than the lowest month.

# %%
customer_sales = (
    df.groupby('Customer Name')['Sales']
    .sum()
    .sort_values(ascending=False)
)

customer_sales.head(10)
# Out:
# Customer Name
# Sean Miller           25043.050
# Tamara Chand          19052.218
# Raymond Buch          15117.339
# Tom Ashbrook          14595.620
# Adrian Barton         14473.571
# Ken Lonsdale          14175.229
# Sanjit Chand          14142.334
# Hunter Lopez          12873.298
# Sanjit Engle          12209.438
# Christopher Conant    12129.072
# Name: Sales, dtype: float64

# %%
top_10_customer_sales = customer_sales.head(10).sum()

total_customer_sales = customer_sales.sum()

top_10_contribution = (
    top_10_customer_sales/total_customer_sales
)*100

print (f'Top 10 customers sales: ${top_10_customer_sales:,.2f}')
print (f'Total  sales : ${total_customer_sales:,.2f}')
print(f'Top 10 customers contributed {top_10_contribution:.2f}% of total sales.')
# Out:
# Top 10 customers sales: $153,811.17
# Total  sales : $2,261,536.78
# Top 10 customers contributed 6.80% of total sales.

# %%
customer_orders = ( 
    df.groupby('Customer Name')['Order ID']
    .nunique()
    .sort_values(ascending=False)
)

customer_orders.head(10)
# Out:
# Customer Name
# Emily Phan             17
# Zuschuss Carroll       13
# Chloris Kastensmidt    13
# Joel Eaton             13
# Patrick Gardner        13
# Rick Bensley           12
# Sally Hughsby          12
# Pete Kriz              12
# Noel Staavos           12
# Resi Pölking           12
# Name: Order ID, dtype: int64

# %%
customer_avg_order = (
    customer_sales/ customer_orders
).sort_values(ascending=False)

customer_avg_order.head(10)
# Out:
# Customer Name
# Sean Miller             5008.610000
# Tamara Chand            3810.443600
# Tom Ashbrook            3648.905000
# Grant Thornton          3117.070667
# Becky Martin            2947.407500
# Mitch Willingham        2626.938000
# Raymond Buch            2519.556500
# Christopher Conant      2425.814400
# Peter Fuller            2265.716000
# Christopher Martinez    2238.505000
# dtype: float64

# %%
customer_segments = pd.qcut(
    customer_sales,
    q=4,
    labels= ['low Value', 'median value', 'High value', 'very High Value']
)

customer_segments.value_counts().sort_index()
# Out:
# Sales
# low Value          199
# median value       198
# High value         198
# very High Value    198
# Name: count, dtype: int64

# %%
segment_sales= (
    customer_sales.groupby(customer_segments)
    .agg(
        total_sales='sum',
        avg_customer_sales='mean',
        customer_count='count'
    )
)

segment_sales
# Out:
#                   total_sales  avg_customer_sales  customer_count
# Sales
# low Value        1.215275e+05          610.690725             199
# median value     3.232647e+05         1632.649801             198
# High value       5.660638e+05         2858.908161             198
# very High Value  1.250681e+06         6316.569960             198

# %%
segment_orders = (
    customer_orders.groupby(customer_segments)
    .agg(
        total_orders='sum',
        avg_orders_per_customer='mean',
        customer_count = 'count'
    )
)

segment_orders
# Out:
#                  total_orders  avg_orders_per_customer  customer_count
# Sales
# low Value                 823                 4.135678             199
# median value             1157                 5.843434             198
# High value               1406                 7.101010             198
# very High Value          1536                 7.757576             198

# %%
segment_aov = (
    segment_sales['total_sales']/segment_orders['total_orders']
).rename('_avg_order_value')

segment_aov
# Out:
# Sales
# low Value          147.663978
# median value       279.399015
# High value         402.605843
# very High Value    814.245346
# Name: _avg_order_value, dtype: float64

# %%
product_sales = (
    df.groupby('Product Name')['Sales']
    .sum()
    .sort_values(ascending=False)
)

product_sales.head(10)
# Out:
# Product Name
# Canon imageCLASS 2200 Advanced Copier                                          61599.824
# Fellowes PB500 Electric Punch Plastic Comb Binding Machine with Manual Bind    27453.384
# Cisco TelePresence System EX90 Videoconferencing Unit                          22638.480
# HON 5400 Series Task Chairs for Big and Tall                                   21870.576
# GBC DocuBind TL300 Electric Binding System                                     19823.479
# GBC Ibimaster 500 Manual ProClick Binding System                               19024.500
# Hewlett Packard LaserJet 3310 Copier                                           18839.686
# HP Designjet T520 Inkjet Large Format Printer - 24" Color                      18374.895
# GBC DocuBind P400 Electric Binding System                                      17965.068
# High Speed Automatic Electric Letter Opener                                    17030.312
# Name: Sales, dtype: float64

# %%
bottom_10_products = (
    product_sales
    .sort_values()
    .head()
)
bottom_10_products
# Out:
# Product Name
# Eureka Disposable Bags for Sanitaire Vibra Groomer I Upright Vac    1.624
# Avery 5                                                             5.760
# Xerox 20                                                            6.480
# Grip Seal Envelopes                                                 7.072
# Acme Serrated Blade Letter Opener                                   7.632
# Name: Sales, dtype: float64

# %%
top_10_product_sales = product_sales.head(10).sum()

total_product_sales = product_sales.sum()

top_10_product_contribution = (
    top_10_product_sales/total_product_sales
    )*100

print(f'Top 10 products sales: ${top_10_product_sales:,.2f}')
print(f'Total sales :$ {total_product_sales:,.2f}')
print(f'Top 10 products  contributed {top_10_product_contribution:,.2f}% of total sales.')
# Out:
# Top 10 products sales: $244,620.20
# Total sales :$ 2,261,536.78
# Top 10 products  contributed 10.82% of total sales.

# %%
product_quantity=(
    df.groupby('Product Name')['Quantity']
    .sum()
    .sort_values(ascending=False)
)

product_quantity.head(10)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[511], line 2
#       1 product_quantity=(
# ----> 2     df.groupby('Product Name')['Quantity']
#       3     .sum()
#       4     .sort_values(ascending=False)
#       5 )
#
# File ~\anaconda3\envs\python_course\Lib\site-packages\pandas\core\groupby\generic.py:2938, in DataFrameGroupBy.__getitem__(self, key)
#    2931 if isinstance(key, tuple) and len(key) > 1:
#    2932     # if len == 1, then it becomes a SeriesGroupBy and this is actually
#    2933     # valid syntax, so don't raise
#    2934     raise ValueError(
#    2935         "Cannot subset columns with a tuple with more than one element. "
#    2936         "Use a list instead."
#    2937     )
# -> 2938 return super().__getitem__(key)
#
# File ~\anaconda3\envs\python_course\Lib\site-packages\pandas\core\base.py:228, in SelectionMixin.__getitem__(self, key)
# ...

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales'],
#       dtype='str')

# %%
subcategory_sales = (
    df.groupby('Sub-Category')['Sales']
    .sum()
    .sort_values(ascending=False)
)

subcategory_sales
# Out:
# Sub-Category
# Phones         327782.4480
# Chairs         322822.7310
# Storage        219343.3920
# Tables         202810.6280
# Binders        200028.7850
# Machines       189238.6310
# Accessories    164186.7000
# Copiers        146248.0940
# Bookcases      113813.1987
# Appliances     104618.4030
# Furnishings     89212.0180
# Paper           76828.3040
# Supplies        46420.3080
# Art             26705.4100
# Envelopes       16128.0460
# Labels          12347.7260
# Fasteners        3001.9600
# Name: Sales, dtype: float64

# %%
top_10_subcategories = subcategory_sales.head(10)

bottom_10_subcategories = subcategory_sales.sort_values().head(10)

print('Top 10 sub_categories:')
print(top_10_subcategories)

print('\nBottom 10 sub-Categories:')
print (bottom_10_subcategories)
# Out:
# Top 10 sub_categories:
# Sub-Category
# Phones         327782.4480
# Chairs         322822.7310
# Storage        219343.3920
# Tables         202810.6280
# Binders        200028.7850
# Machines       189238.6310
# Accessories    164186.7000
# Copiers        146248.0940
# Bookcases      113813.1987
# Appliances     104618.4030
# Name: Sales, dtype: float64
#
# Bottom 10 sub-Categories:
# Sub-Category
# Fasteners        3001.9600
# Labels          12347.7260
# Envelopes       16128.0460
# Art             26705.4100
# Supplies        46420.3080
# Paper           76828.3040
# Furnishings     89212.0180
# Appliances     104618.4030
# Bookcases      113813.1987
# Copiers        146248.0940
# Name: Sales, dtype: float64

# %%
region_sales = (
    df.groupby('Region')['Sales']
    .sum()
    .sort_values(ascending=False)
)

region_sales
# Out:
# Region
# West       710219.6845
# East       669518.7260
# Central    492646.9132
# South      389151.4590
# Name: Sales, dtype: float64

# %%
state_sales= (
    df.groupby('State')['Sales']
    .sum()
    .sort_values(ascending=False)
)

state_sales.head(10)
# Out:
# State
# California      446306.4635
# New York        306361.1470
# Texas           168572.5322
# Washington      135206.8500
# Pennsylvania    116276.6500
# Florida          88436.5320
# Illinois         79236.5170
# Michigan         76136.0740
# Ohio             75130.3500
# Virginia         70636.7200
# Name: Sales, dtype: float64

# %%
bottom_10_states = (
    state_sales
    .sort_values()
    .head(10)
)

bottom_10_states
# Out:
# State
# North Dakota             919.910
# West Virginia           1209.824
# Maine                   1270.530
# South Dakota            1315.560
# Wyoming                 1603.136
# District of Columbia    2865.020
# Kansas                  2914.310
# Idaho                   4382.486
# Iowa                    4443.560
# New Mexico              4783.522
# Name: Sales, dtype: float64

# %%
category_sales = (
    df.groupby('Category')['Sales']
    .sum()
    .sort_values(ascending=False)
)

category_sales
# Out:
# Category
# Technology         827455.8730
# Furniture          728658.5757
# Office Supplies    705422.3340
# Name: Sales, dtype: float64

# %%
category_contribution=(
    category_sales/category_sales.sum()*100
).round(2)

category_contribution
# Out:
# Category
# Technology         36.59
# Furniture          32.22
# Office Supplies    31.19
# Name: Sales, dtype: float64

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales'],
#       dtype='str')

# %%
df['Shipping Days']=(
    df['Ship Date']-df['Order Date']
    ).dt.days

# %%
df['Shipping Days'].describe()
# Out:
# count    9800.000000
# mean        3.961122
# std         1.749614
# min         0.000000
# 25%         3.000000
# 50%         4.000000
# 75%         5.000000
# max         7.000000
# Name: Shipping Days, dtype: float64

# %%
ship_mode_analysis=(
    df.groupby('Ship Mode')['Shipping Days']
    .agg(
        avg_shipping_days= 'mean',
        median_shipping_days='median',
        order_counts='count'
        )
    .sort_values('avg_shipping_days')
)

ship_mode_analysis
# Out:
#                 avg_shipping_days  median_shipping_days  order_counts
# Ship Mode
# Same Day                 0.044610                   0.0           538
# First Class              2.179214                   2.0          1501
# Second Class             3.249211                   3.0          1902
# Standard Class           5.008363                   5.0          5859

# %%
region_shipping =(
    df.groupby('Region')['Shipping Days']
    .agg(
        avg_shipping_days = 'mean',
        median_shipping_days = 'median',
        order_count = 'count'
    )
    .sort_values('avg_shipping_days', ascending=False)
)

region_shipping
# Out:
#          avg_shipping_days  median_shipping_days  order_count
# Region
# Central           4.065876                   4.0         2277
# South             3.961202                   4.0         1598
# West              3.930255                   4.0         3140
# East              3.910233                   4.0         2785

# %%
segement_shipping = (
    df.assign(
        Customer_segment=df['Customer Name'].map(customer_segments)
        )
    .groupby('Customer_segment')['Shipping Days']
    .agg(
        avg_shipping_days = 'mean',
        median_shipping_days = 'median',
        order_count = 'count'
    )
    .sort_values('avg_shipping_days', ascending=False)
)

segement_shipping
# Out:
#                   avg_shipping_days  median_shipping_days  order_count
# Customer_segment
# very High Value            3.997062                   4.0         3404
# High value                 3.978510                   4.0         2885
# median value               3.923186                   4.0         2109
# low Value                  3.895150                   4.0         1402

# %%
order_level=(
    df[
        ['Order ID', 'Customer Name', 'Shipping Days']
    ]
    .drop_duplicates('Order ID')
)

order_level['Customer_segment']= (
    order_level['Customer Name'].map(customer_segments)
)

segment_shipping = (
    order_level.groupby('Customer_segment')['Shipping Days']
    .agg(
        avg_shipping_days ='mean',
        median_shipping_days= 'median',
        order_count = 'count'
    )
    .sort_values('avg_shipping_days', ascending=False)
)

segment_shipping
# Out:
#                   avg_shipping_days  median_shipping_days  order_count
# Customer_segment
# very High Value            3.993490                   4.0         1536
# High value                 3.990754                   4.0         1406
# low Value                  3.917375                   4.0          823
# median value               3.902334                   4.0         1157

# %%
subcategory_performance= (
    df.groupby('Sub-Category')
    .agg(
        total_sales = ('Sales', 'sum'),
        avg_shipping_days=('Shipping Days', 'mean'),
        order_count=('Order ID', 'nunique')
    )
    .sort_values('total_sales', ascending=False)
)

subcategory_performance
# Out:
#               total_sales  avg_shipping_days  order_count
# Sub-Category
# Phones        327782.4480           4.002283          803
# Chairs        322822.7310           3.902801          566
# Storage       219343.3920           3.977163          764
# Tables        202810.6280           3.901274          302
# Binders       200028.7850           4.032842         1291
# Machines      189238.6310           3.747826          112
# Accessories   164186.7000           3.884921          702
# Copiers       146248.0940           3.636364           66
# Bookcases     113813.1987           3.814159          222
# Appliances    104618.4030           3.991285          444
# Furnishings    89212.0180           3.978518          855
# Paper          76828.3040           3.890882         1163
# Supplies       46420.3080           3.945652          181
# Art            26705.4100           4.057325          720
# Envelopes      16128.0460           4.008065          243
# ...

# %%
overall_avg_shipping = df['Shipping Days'].mean()

high_sales_slow_shipping=(
    subcategory_performance[
        (subcategory_performance['total_sales']>subcategory_performance['total_sales'].median())&
        (subcategory_performance['avg_shipping_days']>overall_avg_shipping)
    ]
    .sort_values('total_sales', ascending=False)
)

high_sales_slow_shipping
# Out:
#               total_sales  avg_shipping_days  order_count
# Sub-Category
# Phones         327782.448           4.002283          803
# Storage        219343.392           3.977163          764
# Binders        200028.785           4.032842         1291

# %%
problem_subcategories = ['Phones', 'Binders', 'Storage']

subcategory_ship_mode = (
    df[df['Sub-Category'].isin(problem_subcategories)]
    .groupby(['Sub-Category', 'Ship Mode'])['Shipping Days']
    .agg(['mean', 'median', 'count'])
    .round(2)
    .sort_values(['Sub-Category', 'mean'], ascending=[True, False])
)

subcategory_ship_mode
# Out:
#                              mean  median  count
# Sub-Category Ship Mode
# Binders      Standard Class  5.02     5.0    930
#              Second Class    3.31     3.0    258
#              First Class     2.13     2.0    230
#              Same Day        0.08     0.0     74
# Phones       Standard Class  4.99     5.0    526
#              Second Class    3.38     3.0    173
#              First Class     2.18     2.0    135
#              Same Day        0.05     0.0     42
# Storage      Standard Class  5.04     5.0    497
#              Second Class    3.23     3.0    168
#              First Class     2.24     2.0    116
#              Same Day        0.02     0.0     51

# %%
subcategory_ship_mix = (
    df[df['Sub-Category'].isin (problem_subcategories)]
    .groupby(['Sub-Category', 'Ship Mode'])['Order ID']
    .nunique()
    .unstack(fill_value=0)
)
subcategory_ship_mix
# Out:
# Ship Mode     First Class  Same Day  Second Class  Standard Class
# Sub-Category
# Binders               203        60           227             801
# Phones                125        36           162             480
# Storage               108        46           153             457

# %%
problem_region_shipping = (
    df[df['Sub-Category'].isin (problem_subcategories)]
    .groupby(['Sub-Category', 'Region',])['Shipping Days']
    .agg(['mean', 'median', 'count'])
    .round(2)
    .sort_values(['Sub-Category','mean'],ascending=[True, False])
)

problem_region_shipping
# Out:
#                       mean  median  count
# Sub-Category Region
# Binders      Central  4.15     4.0    362
#              East     4.07     4.0    427
#              South    4.04     4.0    241
#              West     3.91     4.0    462
# Phones       Central  4.05     4.0    197
#              East     4.01     4.0    267
#              West     4.01     4.0    273
#              South    3.91     4.0    139
# Storage      Central  4.10     4.0    205
#              West     4.01     4.0    263
#              East     3.95     4.0    237
#              South    3.77     4.0    127

# %%
central_ship_mix = (
    df[
        (df['Sub-Category'].isin(problem_subcategories))&
        (df['Region']== 'Central')
    ]
    .groupby(['Sub-Category', 'Ship Mode'])['Order ID']
    .nunique()
    .unstack(fill_value=0)
)

central_ship_mix
# Out:
# Ship Mode     First Class  Same Day  Second Class  Standard Class
# Sub-Category
# Binders                46        17            53             198
# Phones                 34         6            36             105
# Storage                20        13            32             121

# %%
region_ship_mode= (
    df[df['Sub-Category'].isin(problem_subcategories)]
    .groupby(['Region', 'Ship Mode'])['Shipping Days']
    .agg(['mean', 'median', 'count'])
    .round(2)
    .sort_values(['Region', 'mean'], ascending=[True, False])
)

region_ship_mode
# Out:
#                         mean  median  count
# Region  Ship Mode
# Central Standard Class  5.02     5.0    483
#         Second Class    3.47     4.0    135
#         First Class     2.33     3.0    105
#         Same Day        0.05     0.0     41
# East    Standard Class  4.97     5.0    578
#         Second Class    3.33     3.0    162
#         First Class     2.25     2.0    146
#         Same Day        0.00     0.0     45
# South   Standard Class  5.00     5.0    303
#         Second Class    3.21     3.0    103
#         First Class     2.04     2.0     73
#         Same Day        0.00     0.0     28
# West    Standard Class  5.07     5.0    589
#         Second Class    3.22     3.0    199
#         First Class     2.04     2.0    157
#         Same Day        0.13     0.0     53

# %%
region_ship_mix = (
    df[df['Sub-Category'].isin(problem_subcategories)]
    .groupby(['Region', 'Ship Mode'])['Order ID']
    .nunique()
    .unstack(fill_value=0)
)

region_ship_mix_pct =(
    region_ship_mix
    .div(region_ship_mix.sum(axis=1), axis=0)
    .mul(100)
    .round(2)
)

region_ship_mix_pct
# Out:
# Ship Mode  First Class  Same Day  Second Class  Standard Class
# Region
# Central          15.87      5.46         17.58           61.09
# East             14.66      4.40         18.48           62.46
# South            14.13      5.33         20.53           60.00
# West             16.73      5.05         19.92           58.30

# %%
product_performance=(
    df[df['Sub-Category'].isin(problem_subcategories)]
    .groupby(['Sub-Category', 'Product Name'])
    .agg(
        total_sales=('Sales', 'sum'),
        avg_shipping_days= ('Shipping Days', 'mean'),
        order_count = ('Order ID', 'nunique')
    )
    .sort_values('total_sales', ascending=False)
)

product_performance.head(20)
# Out:
#                                                                  total_sales  \
# Sub-Category Product Name
# Binders      Fellowes PB500 Electric Punch Plastic Comb Bind...    27453.384
#              GBC DocuBind TL300 Electric Binding System            19823.479
#              GBC Ibimaster 500 Manual ProClick Binding System      19024.500
#              GBC DocuBind P400 Electric Binding System             17965.068
#              Ibico EPK-21 Electric Binding System                  15875.916
# Phones       Samsung Galaxy Mega 6.3                               13943.668
#              Apple iPhone 5                                        12996.600
# Storage      Tennsco 6- and 18-Compartment Lockers                 10076.460
#              Tennsco Double-Tier Lockers                            9630.856
#              Tennsco Single-Tier Lockers                            9158.296
# Phones       Wilson Electronics DB Pro Signal Booster               8878.400
# ...

# %%
overall_avg_shipping=df['Shipping Days'].mean()

high_sales_slow_products = (
    product_performance[
        (product_performance['total_sales']>product_performance['total_sales'].median())&
        (product_performance['avg_shipping_days']>overall_avg_shipping)&
        (product_performance['order_count']>=10)
    ]
    .sort_values('total_sales', ascending=False)
)

high_sales_slow_products
# Out:
#                                                                  total_sales  \
# Sub-Category Product Name
# Binders      Fellowes PB500 Electric Punch Plastic Comb Bind...    27453.384
#              GBC DocuBind TL300 Electric Binding System            19823.479
# Storage      Tennsco 6- and 18-Compartment Lockers                 10076.460
#              Tennsco Double-Tier Lockers                            9630.856
#              Hot File 7-Pocket, Floor Stand                         8138.232
#              Standard Rollaway File with Lock                       6594.954
# Binders      Ibico Hi-Tech Manual Binding System                    5398.323
# Storage      SAFCO Boltless Steel Shelving                          4704.696
# Phones       Pyle PMP37LED                                          3590.026
# Storage      Carina Double Wide Media Storage Towers in Natu...     3028.652
#              Fellowes Bankers Box Stor/Drawer Steel Plus            1426.308
# ...

# %%
top_problem_products = high_sales_slow_products.head(5).index.get_level_values('Product Name')

product_ship_mode = (
    df[df['Product Name'].isin(top_problem_products)]
    .groupby(['Product Name', 'Ship Mode'])['Shipping Days']
    .agg(['mean','median','count'])
    .round(2)
)

product_ship_mode
# Out:
#                                                                    mean  \
# Product Name                                       Ship Mode
# Fellowes PB500 Electric Punch Plastic Comb Bind... First Class     2.50
#                                                    Second Class    2.00
#                                                    Standard Class  6.00
# GBC DocuBind TL300 Electric Binding System         First Class     2.50
#                                                    Standard Class  5.33
# Hot File 7-Pocket, Floor Stand                     First Class     2.50
#                                                    Standard Class  4.82
# Tennsco 6- and 18-Compartment Lockers              Second Class    4.00
#                                                    Standard Class  5.00
# Tennsco Double-Tier Lockers                        First Class     2.00
#                                                    Second Class    3.00
# ...

# %%
product_region_ship = (
    df[df['Product Name'].isin(top_problem_products)]
    .groupby(['Product Name', 'Region', 'Ship Mode',])['Shipping Days']
    .agg(['mean', 'count'])
    .round(2)
)

product_region_ship
# Out:
#                                                                            mean  \
# Product Name                                       Region  Ship Mode
# Fellowes PB500 Electric Punch Plastic Comb Bind... Central First Class     2.50
#                                                            Standard Class  5.00
#                                                    East    First Class     3.00
#                                                            Standard Class  6.00
#                                                    South   Standard Class  6.00
#                                                    West    First Class     2.00
#                                                            Second Class    2.00
#                                                            Standard Class  7.00
# GBC DocuBind TL300 Electric Binding System         Central First Class     3.00
#                                                            Standard Class  4.00
# ...

# %%
standard_class_mix = (
    df[df['Product Name'].isin(top_problem_products)]
    .groupby('Product Name')['Ship Mode']
    .value_counts(normalize=True)
    .mul(100)
    .rename('pct')
    .reset_index()
)

standard_class_mix[
    standard_class_mix['Ship Mode']=='Standard Class'
].sort_values('pct', ascending=False).round(2)
# Out:
#                                         Product Name       Ship Mode    pct
# 5                     Hot File 7-Pocket, Floor Stand  Standard Class  84.62
# 3         GBC DocuBind TL300 Electric Binding System  Standard Class  81.82
# 7              Tennsco 6- and 18-Compartment Lockers  Standard Class  70.00
# 9                        Tennsco Double-Tier Lockers  Standard Class  66.67
# 0  Fellowes PB500 Electric Punch Plastic Comb Bin...  Standard Class  50.00

# %%
df.columns.tolist()
# Out:
# ['Row ID',
#  'Order ID',
#  'Order Date',
#  'Ship Date',
#  'Ship Mode',
#  'Customer ID',
#  'Customer Name',
#  'Segment',
#  'Country',
#  'City',
#  'State',
#  'Postal Code',
#  'Region',
#  'Product ID',
#  'Category',
#  'Sub-Category',
#  'Product Name',
#  'Sales',
#  'Shipping Days']

# %%
product_region_shipping = (
    df[df['Product Name'].isin (top_problem_products)]
    .groupby(['Product Name','Region', 'Ship Mode'])
    .agg(
        avg_shipping_days = ('Shipping Days', 'mean'),
        median_shipping_days = ('Shipping Days', 'median'),
        order_count=('Order ID', 'nunique')
    )
    .round(2)
    .reset_index()
)
product_region_shipping
# Out:
#                                          Product Name   Region  \
# 0   Fellowes PB500 Electric Punch Plastic Comb Bin...  Central
# 1   Fellowes PB500 Electric Punch Plastic Comb Bin...  Central
# 2   Fellowes PB500 Electric Punch Plastic Comb Bin...     East
# 3   Fellowes PB500 Electric Punch Plastic Comb Bin...     East
# 4   Fellowes PB500 Electric Punch Plastic Comb Bin...    South
# 5   Fellowes PB500 Electric Punch Plastic Comb Bin...     West
# 6   Fellowes PB500 Electric Punch Plastic Comb Bin...     West
# 7   Fellowes PB500 Electric Punch Plastic Comb Bin...     West
# 8          GBC DocuBind TL300 Electric Binding System  Central
# 9          GBC DocuBind TL300 Electric Binding System  Central
# 10         GBC DocuBind TL300 Electric Binding System     East
# 11         GBC DocuBind TL300 Electric Binding System     East
# 12         GBC DocuBind TL300 Electric Binding System    South
# 13                     Hot File 7-Pocket, Floor Stand  Central
# ...

# %%
overall_avg_shipping=df['Shipping Days'].mean()

shipping_risk = (
    product_region_shipping[
        (product_region_shipping['avg_shipping_days']>overall_avg_shipping)&
        (product_region_shipping['order_count']>=3)
    ]
.sort_values(
    ['avg_shipping_days', 'order_count'],
    ascending= [False,False]
)
)

shipping_risk
# Out:
#                                   Product Name   Region       Ship Mode  \
# 11  GBC DocuBind TL300 Electric Binding System     East  Standard Class
# 22       Tennsco 6- and 18-Compartment Lockers     West  Standard Class
# 12  GBC DocuBind TL300 Electric Binding System    South  Standard Class
# 13              Hot File 7-Pocket, Floor Stand  Central  Standard Class
# 28                 Tennsco Double-Tier Lockers    South  Standard Class
# 15              Hot File 7-Pocket, Floor Stand     East  Standard Class
# 16              Hot File 7-Pocket, Floor Stand    South  Standard Class
# 19       Tennsco 6- and 18-Compartment Lockers  Central  Standard Class
#
#     avg_shipping_days  median_shipping_days  order_count
# 11               6.00                   6.0            3
# 22               5.50                   5.5            4
# 12               5.20                   5.0            5
# 13               4.75                   4.5            4
# ...

# %%
risk_orders= shipping_risk['order_count'].sum()

problem_product_orders =(
    df[df['Product Name'].isin(top_problem_products)]
    ['Order ID']
    .nunique()
)

risk_order_pct = risk_orders/ problem_product_orders*100
risk_orders, problem_product_orders, round(risk_order_pct,2)
# Out:
# (np.int64(29), 56, np.float64(51.79))

# %%
shipping_risk.groupby('Product Name').agg(
    risky_orders=('order_count', 'sum'),
    avg_risk_shipping= ('avg_shipping_days', 'mean')
).sort_values('risky_orders', ascending=False)
# Out:
#                                             risky_orders  avg_risk_shipping
# Product Name
# Hot File 7-Pocket, Floor Stand                        10           4.583333
# GBC DocuBind TL300 Electric Binding System             8           5.600000
# Tennsco 6- and 18-Compartment Lockers                  7           4.915000
# Tennsco Double-Tier Lockers                            4           4.750000

# %%
problem_product_shipping = (
    df[df['Product Name'].isin(top_problem_products)]
    .groupby('Product Name')
    .agg(
        avg_shipping_days = ('Shipping Days', 'mean'),
        median_shipping_days = ('Shipping Days', 'median'),
        order_count= ('Order ID', 'nunique'),
        total_sales= ('Sales', 'sum')
    )
    .sort_values('avg_shipping_days', ascending = False)
    .round(2)
)

problem_product_shipping
# Out:
#                                                     avg_shipping_days  \
# Product Name
# GBC DocuBind TL300 Electric Binding System                       4.82
# Tennsco 6- and 18-Compartment Lockers                            4.70
# Hot File 7-Pocket, Floor Stand                                   4.46
# Tennsco Double-Tier Lockers                                      4.33
# Fellowes PB500 Electric Punch Plastic Comb Bind...               4.20
#
#                                                     median_shipping_days  \
# Product Name
# GBC DocuBind TL300 Electric Binding System                           5.0
# Tennsco 6- and 18-Compartment Lockers                                4.5
# Hot File 7-Pocket, Floor Stand                                       4.0
# Tennsco Double-Tier Lockers                                          4.5
# Fellowes PB500 Electric Punch Plastic Comb Bind...                   4.0
#
# ...

# %%
df['Order Date']= pd.to_datetime(df['Order Date'])
df['Ship Date'] = pd.to_datetime(df['Ship Date'])

df['Shipping Days']= (
    df['Ship Date']-df['Order Date']
).dt.days

# %%
df[['Order Date', 'Ship Date', 'Shipping Days']].head()
# Out:
#   Order Date  Ship Date  Shipping Days
# 0 2017-11-08 2017-11-11              3
# 1 2017-11-08 2017-11-11              3
# 2 2017-06-12 2017-06-16              4
# 3 2016-10-11 2016-10-18              7
# 4 2016-10-11 2016-10-18              7

# %%
overall_shipping_summary = pd.Series({
    'Overall Avg Shipping Days': df['Shipping Days'].mean(),
    'Problem Products Avg Shipping Days':(
        df[df['Product Name'].isin(top_problem_products)]['Shipping Days'].mean()
    )
})

overall_shipping_summary.round(2)
# Out:
# Overall Avg Shipping Days             3.96
# Problem Products Avg Shipping Days    4.50
# dtype: float64

# %%
shipping_risk
# Out:
#                                   Product Name   Region       Ship Mode  \
# 11  GBC DocuBind TL300 Electric Binding System     East  Standard Class
# 22       Tennsco 6- and 18-Compartment Lockers     West  Standard Class
# 12  GBC DocuBind TL300 Electric Binding System    South  Standard Class
# 13              Hot File 7-Pocket, Floor Stand  Central  Standard Class
# 28                 Tennsco Double-Tier Lockers    South  Standard Class
# 15              Hot File 7-Pocket, Floor Stand     East  Standard Class
# 16              Hot File 7-Pocket, Floor Stand    South  Standard Class
# 19       Tennsco 6- and 18-Compartment Lockers  Central  Standard Class
#
#     avg_shipping_days  median_shipping_days  order_count
# 11               6.00                   6.0            3
# 22               5.50                   5.5            4
# 12               5.20                   5.0            5
# 13               4.75                   4.5            4
# ...

# %%
yearly_sales = (
    df.groupby(df['Order Date'].dt.year)['Sales']
    .sum()
    .sort_index()
    .round(2)
)

yearly_sales
# Out:
# Order Date
# 2015    479856.21
# 2016    459436.01
# 2017    600192.55
# 2018    722052.02
# Name: Sales, dtype: float64
